# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.axis([0,8,0,25])
plt.title("City Rain Fall and Accidents Forecast")
plt.xlabel("Day of a Month",color='cyan')
plt.ylabel("Count",color='magenta')
plt.text(1,2,'Day1-RF')
plt.text(2,5,'Day2-RF')
plt.text(3,9.8,'Day3-RF')
plt.text(4,16,'Day4-RF')
plt.text(2,1.3,'Day1-Acc')
plt.text(3,4,'Day2-Acc')
plt.text(4,8.5,'Day3-Acc')
plt.text(5,15.5,'Day4-Acc')
plt.text(1.1,12,'$y = 2x^2+4$',fontsize=20,bbox={'facecolor':'yellow','alpha':0.3})
plt.grid()
plt.plot([1,2,3,4],[1,4,9,16],'r--')
plt.plot([2,3,4,5],[1,3.5,8,15],'g-')
plt.legend(['Rain Fall','Accidents'],loc='right')

# %%
g = [0,10,20,30,40,50]
x = [36.5,35.5,33,31,18,12]
y = [0,5,10,15,20,25,30,35,40]
labels = ['0%','10%','20%','30%','40%','50%']
plt.plot(g,x,'g-')
plt.plot(g,[33.5,32,27,25,14,9],'b-')
plt.plot(g,[31,24,22.5,19,11,7],'r-')
plt.xticks(g,labels)
plt.yticks(y,[40,45,50,55,60,65,70,75,80])
plt.xlabel('Label Corruption')
plt.ylabel('Classification Accuracy')
plt.legend(['CNN+LSTM+RMLC','RML_CNN','WARP'],loc='lower left')
plt.grid()

# %%
x=[1,2,3,4,5,6,7]
y=[1,2,3]
l=['9 am','10 am','11 am','12 noon','1 pm','2 pm','3 pm']
r=['30°C','35°C','40°C']
plt.xticks(x,l)
plt.yticks(y,r)
plt.plot([1,2,3,4,5,6,7],[2,2.2,2.8,2.6,2.3,2.3,2.4],'ro-')

# %%
import numpy as np
df = pd.DataFrame(np.random.rand(4,4))
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([21.429, 10.714, 39.286, 21.429, 7.143])
mylabels = ["Bio Tech", "Civil", "Mech", "ECE", "CSE"]
myexplode = [0, 0, 0, 0.2, 0.5]

plt.pie(y, labels = mylabels, explode = myexplode, autopct='%1.1f%%', shadow = True)
# Out:
# ([<matplotlib.patches.Wedge at 0x235ff7f1e40>,
# ...
#  [Text(0.8600100027826257, 0.685844585247874, 'Bio Tech'),
#   Text(-0.12316217009117235, 1.0930832904488264, 'Civil'),
#   Text(-1.0930852304501513, -0.12314495106068973, 'Mech'),
#   Text(0.5640356701375165, -1.1712658804953395, 'ECE'),
#   Text(1.5598838558931407, -0.356037015103693, 'CSE')],
#  [Text(0.4690963651541594, 0.3740970464988403, '21.4%'),
#   Text(-0.06717936550427582, 0.5962272493357235, '10.7%'),
#   Text(-0.5962283075182643, -0.06716997330583076, '39.3%'),
#   Text(0.3470988739307794, -0.7207790033817474, '21.4%'),
#   Text(1.072420150926534, -0.2447754478837889, '7.1%')])

# %%
labels = 'Grocery,Automobile,Utitlity Bills,Dining out,Healthcare,Saving,Other Expenses'.split(',')
percent = [21,22,12,8,6,23,8]
plt.pie(percent,
        labels=labels,
        startangle=0,
        shadow=True,
        explode=[0,0.4,0,0,0,0.6,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x235ffa5ae60>,
# ...
#  [Text(0.8691705275003082, 0.6741977411151984, 'Grocery'),
#   Text(-0.638668876352072, 1.3572406074013488, 'Automobile'),
#   Text(-1.0978293973263735, 0.0690696341818306, 'Utitlity Bills'),
#   Text(-0.9287607599924328, -0.5894094083896854, 'Dining out'),
#   Text(-0.5894095496945729, -0.9287606703176233, 'Healthcare'),
#   Text(0.5758543491050689, -1.5994973487370268, 'Saving'),
#   Text(1.065441459568915, -0.27355894471148295, 'Other Expenses')])
